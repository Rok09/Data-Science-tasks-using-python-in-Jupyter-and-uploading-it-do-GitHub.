# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Ryan's notebook

# %% [markdown]
# # Introduction
#
# Welcome to this Ryan's Jupyter Notebook! In this notebook, we will explore, analyze and review my answers to the peer graded assignment.
# Whether you are a beginner or an experienced data scientist, I hope you find this journey insightful and enjoyable.
#
# ## Objectives
#
# Exercise 2 - Create a markdown cell with the title of the notebook. (1 pt)
#
# Exercise 3 - Create a markdown cell for an introduction. (1 pt)
#
# Exercise 4 - Create a markdown cell to list data science languages. (3 pts)
#
# Exercise 5 - Create a markdown cell to list data science libraries. (3 pts)
#
# Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)
#
# Exercise 7 - Create a markdown cell introducing arithmetic expression examples. (1 pt)
#
# Exercise 8 - Create a code cell to multiply and add numbers. (2 pts)
#
# Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)
#
# Exercise 10 -Insert a markdown cell to list Objectives. (3 pts)
#
# Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)
#
# Exercise 12 - Share your notebook through GitHub (3 pts)
#
# Exercise 13 - Take a screenshot of the first page of the notebook. (1 pt)
#
#
# Feel free to run the cells, modify the code, and interact with the content. If you have any questions, comments, or suggestions, don't hesitate to reach out. Let's get started!

# %% [markdown]
# # Data Science Languages
#
# Data science involves working with various programming languages to analyze, visualize, and interpret data. Here are some popular languages used in data science:
#
# 1. **Python**
#    - Widely used for data analysis, machine learning, and scientific computing.
#    - Rich ecosystem of libraries such as NumPy, Pandas, Matplotlib, and scikit-learn.
#
# 2. **R**
#    - Specialized for statistical computing and graphics.
#    - Commonly used in academia and research.
#
# 3. **SQL (Structured Query Language)**
#    - Essential for working with relational databases.
#    - Used to query, manipulate, and analyze structured data.
#
# 4. **Julia**
#    - Known for its high-performance capabilities in numerical and scientific computing.
#
# 5. **Java**
#    - Used for big data processing, especially with Apache Hadoop and Apache Spark.
#
# 6. **Scala**
#    - Frequently used in combination with Apache Spark for distributed computing.
#
# These languages offer diverse capabilities and are chosen based on the specific requirements of a data science project.

# %% [markdown]
# # Data Science Libraries
#
# In data science, various libraries play a crucial role in performing tasks such as data manipulation, analysis, visualization, and machine learning. Here are some popular Python libraries commonly used in the data science field:
#
# 1. **NumPy**
#    - Fundamental package for scientific computing with support for large, multi-dimensional arrays and matrices.
#
# 2. **Pandas**
#    - Data manipulation library that provides data structures like DataFrame for efficient data analysis.
#
# 3. **Matplotlib**
#    - 2D plotting library for creating static, animated, and interactive visualizations.
#
# 4. **Seaborn**
#    - Statistical data visualization library based on Matplotlib, providing a high-level interface for drawing attractive and informative statistical graphics.
#
# 5. **Scikit-learn**
#    - Simple and efficient tools for data mining and data analysis, particularly for machine learning.
#
# 6. **TensorFlow**
#    - Open-source machine learning library developed by Google, widely used for building and training deep learning models.
#
# 7. **PyTorch**
#    - Open-source machine learning library, particularly popular for its dynamic computation graph and ease of use in deep learning.
#
# 8. **NLTK (Natural Language Toolkit)**
#    - Library for working with human language data, including processing and analysis.
#
# 9. **Statsmodels**
#    - Library for estimating and testing statistical models.
#
# 10. **Beautiful Soup**
#     - Library for pulling data out of HTML and XML files, commonly used for web scraping.
#
# These libraries, among many others, form the foundation of the Python ecosystem for data science.

# %% [markdown]
# # Data Science Tools
#
# | Tool Name        | Description                                       |
# |------------------|---------------------------------------------------|
# | **Jupyter Notebook** | Interactive computing and data visualization.     |
# | **RStudio**        | Integrated development environment for R.          |
# | **Python**         | General-purpose programming language for data science. |
# | **Tableau**        | Business intelligence and data visualization tool. |
# | **SQL**            | Query language for managing and manipulating databases. |
# | **Git**            | Version control system for tracking changes in code. |
# | **Excel**          | Spreadsheet software with data analysis capabilities. |
# | **Apache Spark**   | Open-source distributed computing system.           |
# | **Hadoop**         | Framework for distributed storage and processing of large data sets. |
# | **TensorBoard**    | Visualization toolkit for TensorFlow.              |
#
# These tools cater to different aspects of the data science workflow, including data analysis, visualization, programming, and machine learning.

# %% [markdown]
# # Arithmetic Expressions Examples
#
# Arithmetic expressions involve mathematical operations such as addition, subtraction, multiplication, and division. They are fundamental in programming and data analysis. Here are some examples:
#
# 1. Addition:
# result = 5 + 3   # Adds 5 and 3, result is 8
#
# 2. Subtraction:
# result = 10 - 4  # Subtracts 4 from 10, result is 6
#
# 3. Multiplication:
# result = 6 * 7   # Multiplies 6 and 7, result is 42
#
# 4. Division:
# result = 15 / 3  # Divides 15 by 3, result is 5.0 (float division)
#
# Remember to use parentheses () to control the order of operations if needed. These basic arithmetic operations serve as the building blocks for more complex calculations in data science and programming.

# %%
number1 = 5
number2 = 3

result_multiply = number1 * number2
result_add = number1 + number2

print(f"Multiplication Result: {result_multiply}")
print(f"Addition Result: {result_add}")
# Out:
# Multiplication Result: 15
# Addition Result: 8

# %%
minutes = 120
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours")
# Out:
# 120 minutes is equal to 2.0 hours

# %% [markdown]
# ## Objectives
#
# 1. Understand the basics of Python programming.
# 2. Learn how to perform arithmetic operations in Python.
# 3. Explore variables and data types.
# 4. Gain familiarity with Jupyter Notebook environment.
# 5. Practice creating and running code cells.
# 6. Convert minutes to hours using Python.
# 7. Customize and modify code for specific scenarios.

# %% [markdown]
# ## Author
#
# **Ryan Mathew**
